# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %%
url='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
df_drinks=pd.read_csv(url)
df_drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
df_beerP=df_drinks.sort_values(by='beer_servings',ascending=False)
df_beerP
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 117         Namibia            376                3              1
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 98        Lithuania            343              244             56
# ..              ...            ...              ...            ...
# 107      Mauritania              0                0              0
# 158         Somalia              0                0              0
# 111          Monaco              0                0              0
# 128        Pakistan              0                0              0
# 0       Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8        AF
# 45                           11.8        EU
# ...

# %%
df_beerP.reset_index().query('country == "Spain"')
# Out:
#     index country  beer_servings  spirit_servings  wine_servings  \
# 12    160   Spain            284              157            112
#
#     total_litres_of_pure_alcohol continent
# 12                          10.0        EU

# %%
df_g=df_drinks.groupby('continent')
df_g

# %%
df_eu=df_g.get_group('EU')
df_eu
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 7               Armenia             21              179             11
# 9               Austria            279               75            191
# 10           Azerbaijan             21               46              5
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=df_eu.beer_servings,y=df_eu.wine_servings, label='EU')
plt.legend()
# Out:
# Text(50, 25, 'Hola')

# %%
df_af=df_g.get_group('AF')
df_af
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 2                     Algeria             25                0             14
# 4                      Angola            217               57             45
# 18                      Benin             34                4             13
# 22                   Botswana            173               35             35
# 26               Burkina Faso             25                7              7
# 27                    Burundi             88                0              0
# 28              Cote d'Ivoire             37                1              7
# 29                 Cabo Verde            144               56             16
# 31                   Cameroon            147                1              4
# 33   Central African Republic             17                2              1
# 34                       Chad             15                1              1
# ...

# %%
plt.scatter(x=df_eu.beer_servings,y=df_eu.wine_servings, label='EU')
plt.scatter(x=df_af.beer_servings,y=df_af.wine_servings, label='AF')
plt.legend()

# %%
df_drinks.fillna(value="NA",inplace=True)
continentes=df_drinks.continent.unique()
continentes
# Out:
# array(['AS', 'EU', 'AF', 'NA', 'SA', 'OC'], dtype=object)

# %%
for continente in continentes:
    df_c=df_g.get_group(continente)
    plt.scatter(x=df_c.beer_servings,y=df_c.wine_servings, label=continente)
plt.legend()

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
df_eu=df_g.get_group('EU')
plt.bar(x=df_eu.country,height=df_eu.wine_servings)
# Out:
# <BarContainer object of 45 artists>

# %%
for continente in continentes:
    df_c=df_g.get_group(continente)
    plt.bar(x=continente,height=df_c.wine_servings)

# %%
df_c
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 8           Australia            261               72            212
# 40       Cook Islands              0              254             74
# 59               Fiji             77               35              1
# 89           Kiribati             21               34              1
# 106  Marshall Islands              0                0              0
# 110        Micronesia             62               50             18
# 118             Nauru             49                0              8
# 121       New Zealand            203               79            175
# 125              Niue            188              200              7
# 129             Palau            306               63             23
# 131  Papua New Guinea             44               39              1
# 146             Samoa            105               18             24
# 157   Solomon Islands             56               11              1
# ...

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
df_drinks.groupby('continent').mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# NA            145.434783       165.739130      24.521739
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# NA                             5.995652
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
df_drinks.groupby('continent').median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# NA                 143.0            137.0           11.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# NA                                 6.30
# OC                                 1.75
# SA                                 6.85

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
df_drinks.agg(['mean','min','max'])
# Out:
# C:\Users\holacons\AppData\Local\Temp\ipykernel_15640\2378793778.py:1: FutureWarning: ['country', 'continent'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df_drinks.agg(['mean','min','max'])
#           country  beer_servings  spirit_servings  wine_servings  \
# mean          NaN     106.160622        80.994819      49.450777
# min   Afghanistan       0.000000         0.000000       0.000000
# max      Zimbabwe     376.000000       438.000000     370.000000
#
#       total_litres_of_pure_alcohol continent
# mean                      4.717098       NaN
# min                       0.000000        AF
# max                      14.400000        SA

# %%
df_drinks.spirit_servings.agg(['mean','min','max'])
# Out:
# mean     80.994819
# min       0.000000
# max     438.000000
# Name: spirit_servings, dtype: float64
