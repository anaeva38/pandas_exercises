# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %%
url='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
url
# Out:
# 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
df_users=pd.read_csv(url,sep='|')
df_users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
df_users.groupby('occupation').mean()['age']
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
res = df_users.groupby(['occupation','gender']).size().groupby('occupation').apply(lambda x: x/x.sum())
res
# Out:
# occupation     gender
# administrator  F         0.455696
#                M         0.544304
# artist         F         0.464286
#                M         0.535714
# doctor         M         1.000000
# educator       F         0.273684
#                M         0.726316
# engineer       F         0.029851
#                M         0.970149
# entertainment  F         0.111111
#                M         0.888889
# executive      F         0.093750
#                M         0.906250
# healthcare     F         0.687500
#                M         0.312500
# homemaker      F         0.857143
#                M         0.142857
# lawyer         F         0.166667
#                M         0.833333
# librarian      F         0.568627
#                M         0.431373
# marketing      F         0.384615
#                M         0.615385
# none           F         0.444444
#                M         0.555556
# other          F         0.342857
#                M         0.657143
# ...

# %%
res.reset_index(name='porcen').query('gender == "M"')
# Out:
#        occupation gender    porcen
# 1   administrator      M  0.544304
# 3          artist      M  0.535714
# 4          doctor      M  1.000000
# 6        educator      M  0.726316
# 8        engineer      M  0.970149
# 10  entertainment      M  0.888889
# 12      executive      M  0.906250
# 14     healthcare      M  0.312500
# 16      homemaker      M  0.142857
# 18         lawyer      M  0.833333
# 20      librarian      M  0.431373
# 22      marketing      M  0.615385
# 24           none      M  0.555556
# 26          other      M  0.657143
# 28     programmer      M  0.909091
# 30        retired      M  0.928571
# 32       salesman      M  0.750000
# 34      scientist      M  0.903226
# 36        student      M  0.693878
# 38     technician      M  0.962963
# 40         writer      M  0.577778

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
df_users.groupby('occupation').describe()
# Out:
#               user_id                                                        \
#                 count        mean         std    min     25%    50%     75%
# occupation
# administrator    79.0  430.949367  281.302962    7.0  185.00  436.0  702.00
# artist           28.0  451.892857  322.963860   23.0  149.00  421.5  823.75
# doctor            7.0  533.714286  330.491913  138.0  275.00  427.0  843.00
# educator         95.0  466.905263  250.727201   13.0  242.50  485.0  641.50
# engineer         67.0  456.328358  261.663697   25.0  249.50  467.0  649.00
# entertainment    18.0  398.000000  295.854098   16.0  153.50  381.0  537.25
# executive        32.0  422.312500  287.533049    6.0  184.75  346.0  723.25
# healthcare       16.0  501.437500  261.480393   60.0  343.25  563.5  688.50
# homemaker         7.0  443.000000  345.112059   20.0  195.50  362.0  715.00
# lawyer           12.0  359.083333  251.926562   10.0  152.25  352.0  480.25
# ...

# %%
df_users.groupby('occupation').agg(['min','max'])
# Out:
#               user_id      age     gender     zip_code
#                   min  max min max    min max      min    max
# occupation
# administrator       7  940  21  70      F   M    02154  V1G4L
# artist             23  920  19  48      F   M    01945  V5A2B
# doctor            138  935  28  64      M   M    47401  97405
# educator           13  937  23  63      F   M    01602  M4J2K
# engineer           25  934  22  70      F   M    00000  T8H1N
# entertainment      16  926  15  50      F   M    01040  V3N4P
# executive           6  901  22  69      F   M    00000  L1V3W
# healthcare         60  910  22  62      F   M    02154  97232
# homemaker          20  898  20  50      F   M    17331  96349
# lawyer             10  846  21  53      F   M    06371  90703
# librarian          19  942  23  69      F   M    01080  99603
# marketing          46  881  24  55      F   M    01913  97215
# none               57  756  11  55      F   M    21206  94619
# ...

# %%
df_users.groupby('occupation').age.agg(['min','max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
df_users.groupby(['occupation','gender']).describe()
# Out:
#                      user_id                                                \
#                        count        mean         std    min     25%    50%
# occupation    gender
# administrator F         36.0  443.944444  284.320538   34.0  178.50  438.5
#               M         43.0  420.069767  281.650780    7.0  190.50  394.0
# artist        F         13.0  432.153846  345.109607   23.0  123.00  410.0
#               M         15.0  469.000000  313.686604   31.0  175.50  433.0
# doctor        M          7.0  533.714286  330.491913  138.0  275.00  427.0
# educator      F         26.0  454.730769  267.531315   15.0  215.00  467.5
#               M         69.0  471.492754  245.985331   13.0  295.00  486.0
# engineer      F          2.0  806.500000   28.991378  786.0  796.25  806.5
#               M         65.0  445.553846  258.156144   25.0  247.00  435.0
# entertainment F          2.0  780.000000   83.438600  721.0  750.50  780.0
# ...

# %%
df_users.groupby(['occupation','gender']).age.agg(['min','max'])
# Out:
#                       min  max
# occupation    gender
# administrator F        22   62
#               M        21   70
# artist        F        19   48
#               M        20   45
# doctor        M        28   64
# educator      F        23   51
#               M        25   63
# engineer      F        23   36
#               M        22   70
# entertainment F        24   38
#               M        15   50
# executive     F        39   49
#               M        22   69
# healthcare    F        22   53
#               M        28   62
# homemaker     F        20   50
#               M        23   23
# lawyer        F        28   51
#               M        21   53
# librarian     F        26   59
#               M        23   69
# marketing     F        24   50
#               M        24   55
# none          F        26   55
#               M        11   33
# other         F        18   55
#               M        13   64
# programmer    F        26   38
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
df_users.groupby(['occupation','gender']).size().groupby('occupation').sum()
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# dtype: int64

# %%
df_users.groupby(['occupation','gender']).size().groupby('occupation').apply(lambda x: x/x.sum())
# Out:
# occupation     gender
# administrator  F         0.455696
#                M         0.544304
# artist         F         0.464286
#                M         0.535714
# doctor         M         1.000000
# educator       F         0.273684
#                M         0.726316
# engineer       F         0.029851
#                M         0.970149
# entertainment  F         0.111111
#                M         0.888889
# executive      F         0.093750
#                M         0.906250
# healthcare     F         0.687500
#                M         0.312500
# homemaker      F         0.857143
#                M         0.142857
# lawyer         F         0.166667
#                M         0.833333
# librarian      F         0.568627
#                M         0.431373
# marketing      F         0.384615
#                M         0.615385
# none           F         0.444444
#                M         0.555556
# other          F         0.342857
#                M         0.657143
# ...
